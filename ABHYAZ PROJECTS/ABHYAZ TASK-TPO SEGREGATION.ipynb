# %% [markdown]
# # TPO SEGREGATION

# %%
import pandas as pd
import datetime
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **INPUT DATA**

# %%
import os
os.getcwd()
os.chdir("D:\ABHYAZ INTERNSHIP\output2")

# %% [markdown]
# **EXPLORING THE DATA**

# %%
TPOS = pd.read_excel(r'TPO Contacts.xlsx')
TPOS.head(10)
# Out:
#      Contact Id                                       Account Name  \
# 0  3.304295e+18                          Assam Engineering College
# 1  3.304295e+18  Jawaharlal Nehru Technological University Kaki...
# 2  3.304295e+18                 RGM Group of Institutions, Nandyal
# 3  3.304295e+18                       Abhyaz Internship Applicants
# 4  3.304295e+18                       Abhyaz Internship Applicants
# 5  3.304295e+18                                                NaN
# 6  3.304295e+18                R.V.R. & J.C.College of Engineering
# 7  3.304295e+18               Thadomal Shahani Engineering College
# 8  3.304295e+18        Sardar Patel college of engineering, Mumbai
# 9  3.304295e+18        Dwarkadas J. Sanghvi College of Engineering
#
#                 Mobile                                  Email  \
# 0           9365995608                          tnp@aec.ac.in
# 1           8842351502        placementofficer@jntucek.edu.in
# ...

# %%
TPOS.shape
# Out:
# (674, 13)

# %%
# displaying the column names
TPOS.columns.values
# Out:
# array(['Contact Id', 'Account Name', 'Mobile', 'Email', 'Title',
#        'Contact Role', 'Contact Frequency', 'Indian State', 'Instagram',
#        'Linkedin', 'FB', 'First Name', 'Last Name'], dtype=object)

# %%
TPOS.dtypes
# Out:
# Contact Id           float64
# Account Name          object
# Mobile                object
# Email                 object
# Title                 object
# Contact Role          object
# Contact Frequency     object
# Indian State          object
# Instagram            float64
# Linkedin              object
# FB                    object
# First Name            object
# Last Name             object
# dtype: object

# %%
pip install summarytools
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from summarytools import dfSummary

# %%
dfSummary(TPOS)
# Out:
# <style type="text/css">
# #T_9c1f3 thead>tr>th {
#   text-align: left;
# }
# #T_9c1f3_row0_col0, #T_9c1f3_row1_col0, #T_9c1f3_row2_col0, #T_9c1f3_row3_col0, #T_9c1f3_row4_col0, #T_9c1f3_row5_col0, #T_9c1f3_row6_col0, #T_9c1f3_row7_col0, #T_9c1f3_row8_col0, #T_9c1f3_row9_col0, #T_9c1f3_row10_col0, #T_9c1f3_row11_col0, #T_9c1f3_row12_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_9c1f3_row0_col1, #T_9c1f3_row1_col1, #T_9c1f3_row2_col1, #T_9c1f3_row3_col1, #T_9c1f3_row4_col1, #T_9c1f3_row5_col1, #T_9c1f3_row6_col1, #T_9c1f3_row7_col1, #T_9c1f3_row8_col1, #T_9c1f3_row9_col1, #T_9c1f3_row10_col1, #T_9c1f3_row11_col1, #T_9c1f3_row12_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# ...

# %% [markdown]
# **DATA CLEANING**

# %%
TPOS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 674 entries, 0 to 673
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Contact Id         674 non-null    float64
#  1   Account Name       667 non-null    object
#  2   Mobile             437 non-null    object
#  3   Email              663 non-null    object
#  4   Title              674 non-null    object
#  5   Contact Role       615 non-null    object
#  6   Contact Frequency  358 non-null    object
#  7   Indian State       590 non-null    object
#  8   Instagram          0 non-null      float64
#  9   Linkedin           8 non-null      object
#  10  FB                 2 non-null      object
#  11  First Name         599 non-null    object
#  12  Last Name          674 non-null    object
# dtypes: float64(2), object(11)
# memory usage: 68.6+ KB

# %%
# gets all null values
TPOS.isna()
# Out:
#      Contact Id  Account Name  Mobile  Email  Title  Contact Role  \
# 0         False         False   False  False  False         False
# 1         False         False   False  False  False          True
# 2         False         False   False  False  False         False
# 3         False         False   False  False  False          True
# 4         False         False   False  False  False          True
# ..          ...           ...     ...    ...    ...           ...
# 669       False         False   False  False  False         False
# 670       False         False    True  False  False          True
# 671       False         False   False  False  False         False
# 672       False         False   False  False  False         False
# 673       False         False   False  False  False         False
#
#      Contact Frequency  Indian State  Instagram  Linkedin    FB  First Name  \
# 0                False         False       True      True  True       False
# ...

# %%
TPOS.isnull().any()
# Out:
# Contact Id           False
# Account Name          True
# Mobile                True
# Email                 True
# Title                False
# Contact Role          True
# Contact Frequency     True
# Indian State          True
# Instagram             True
# Linkedin              True
# FB                    True
# First Name            True
# Last Name            False
# dtype: bool

# %%
TPOS.isnull().sum()
# Out:
# Contact Id             0
# Account Name           7
# Mobile               237
# Email                 11
# Title                  0
# Contact Role          59
# Contact Frequency    316
# Indian State          84
# Instagram            674
# Linkedin             666
# FB                   672
# First Name            75
# Last Name              0
# dtype: int64

# %%
TPOS.duplicated().sum()
# Out:
# 0

# %%
TPOS['Indian State'].unique()
# Out:
# array(['Assam', nan, 'Maharashtra', 'Karnataka', 'Tamil Nadu',
#        'Himachal Pradesh', 'Andhra Pradesh', 'Uttar Pradesh',
#        'Madhya Pradesh', 'Bihar', 'Rajasthan', 'Telangana', 'Gujarat',
#        'Punjab', 'Tripura', 'Uttarakhand', 'Manipur', 'Jammu & Kashmir',
#        'West Bengal', 'Haryana', 'Delhi (NCR)', 'Kerala', 'Sikkim', 'Goa',
#        'Jharkhand', 'Odisha', 'Chhattisgarh', 'Puducherry', 'Meghalaya',
#        'Arunachal Pradaesh', 'Mizoram', 'Chandigarh', 'Export',
#        'Andhra Pardesh', 'Jammu and Kashmir'], dtype=object)

# %%
TPOS['Indian State'] = TPOS['Indian State'].str.replace('Jammu and Kashmir', 'Jammu & Kashmir')
TPOS['Indian State'] = TPOS['Indian State'].str.replace('Andhra Pardesh', 'Andhra Pradesh')

# %%
TPOS = TPOS.drop(index=4)
TPOS = TPOS.drop(index=5)

# %%
# replace missing values with zero

#TPOS = TPOS.replace(np.nan, 0)
#TPOS

# %%
TPOS.describe()
# Out:
#          Contact Id  Instagram
# count  6.720000e+02        0.0
# mean   3.304295e+18        NaN
# std    1.505362e+07        NaN
# min    3.304295e+18        NaN
# 25%    3.304295e+18        NaN
# 50%    3.304295e+18        NaN
# 75%    3.304295e+18        NaN
# max    3.304295e+18        NaN

# %%
column = TPOS['Account Name']

column.count()
# Out:
# 666

# %%
# Groupby state Name

TPOS3 = TPOS['Account Name'].value_counts().reset_index()
TPOS3.columns = ['Account Name', 'count']
print(TPOS3)
# Out:
#                                           Account Name  count
# 0      Indian Institute of Technology, (BHU), Varanasi     12
# 1    Dr. B.R. Ambedkar National Institute of Techno...      9
# 2    Indian Institute of Information Technology, De...      9
# 3              INDIAN INSTITUTE OF TECHNOLOGY TIRUPATI      8
# 4          National Institute of Technology Jamshedpur      8
# ..                                                 ...    ...
# 337                                     GLA University      1
# 338                     Srinivas School of Engineering      1
# 339                           DIT University, Dehradun      1
# 340         St. JOSEPH COLLEGE OF ENGINEERING, CHENNAI      1
# 341                     ARCHANA COLLEGE OF ENGINEERING      1
#
# [342 rows x 2 columns]

# %%
TPOS.drop(['Instagram', 'Linkedin','FB'], axis=1, inplace=True)

# %%
TPOS.head(10)
# Out:
#       Contact Id                                       Account Name  \
# 0   3.304295e+18                          Assam Engineering College
# 1   3.304295e+18  Jawaharlal Nehru Technological University Kaki...
# 2   3.304295e+18                 RGM Group of Institutions, Nandyal
# 3   3.304295e+18                       Abhyaz Internship Applicants
# 6   3.304295e+18                R.V.R. & J.C.College of Engineering
# 7   3.304295e+18               Thadomal Shahani Engineering College
# 8   3.304295e+18        Sardar Patel college of engineering, Mumbai
# 9   3.304295e+18        Dwarkadas J. Sanghvi College of Engineering
# 10  3.304295e+18           Vasavi College of Engineering -Hyderabad
# 11  3.304295e+18                                      Ashok Leyland
#
#             Mobile                            Email  \
# 0       9365995608                    tnp@aec.ac.in
# 1       8842351502  placementofficer@jntucek.edu.in
# 2       9885937384                tpospec@gmail.com
# ...

# %%
column_name = 'Mobile'
replace_symbols = ['.','(',')','+']
TPOS[column_name] = TPOS[column_name].replace(replace_symbols).str.strip()
TPOS.head()
# Out:
#      Contact Id                                       Account Name  \
# 0  3.304295e+18                          Assam Engineering College
# 1  3.304295e+18  Jawaharlal Nehru Technological University Kaki...
# 2  3.304295e+18                 RGM Group of Institutions, Nandyal
# 3  3.304295e+18                       Abhyaz Internship Applicants
# 6  3.304295e+18                R.V.R. & J.C.College of Engineering
#
#        Mobile                            Email  \
# 0  9365995608                    tnp@aec.ac.in
# 1  8842351502  placementofficer@jntucek.edu.in
# 2  9885937384                tpospec@gmail.com
# 3  8587077061              sdureja03@gmail.com
# 6         NaN           gsprasad@rvrjcce.ac.in
#
#                                       Title Contact Role Contact Frequency  \
# 0              Training & Placement Officer   Influencer        Frequently
# 1            Training and Placement Officer          NaN               NaN
# ...

# %%
df_1 = TPOS.iloc[:28,:]
df_2 = TPOS.iloc[28:,:]
print("Shape of new dataframes - {} , {}".format(df_1.shape, df_2.shape))
# Out:
# Shape of new dataframes - (28, 10) , (644, 10)

# %%
df_1
# Out:
#       Contact Id                                       Account Name  \
# 0   3.304295e+18                          Assam Engineering College
# 1   3.304295e+18  Jawaharlal Nehru Technological University Kaki...
# 2   3.304295e+18                 RGM Group of Institutions, Nandyal
# 3   3.304295e+18                       Abhyaz Internship Applicants
# 6   3.304295e+18                R.V.R. & J.C.College of Engineering
# 7   3.304295e+18               Thadomal Shahani Engineering College
# 8   3.304295e+18        Sardar Patel college of engineering, Mumbai
# 9   3.304295e+18        Dwarkadas J. Sanghvi College of Engineering
# 10  3.304295e+18           Vasavi College of Engineering -Hyderabad
# 11  3.304295e+18                                      Ashok Leyland
# 12  3.304295e+18                        Graphic Era Hill University
# 13  3.304295e+18            Koneru Lakshmiah College of Engineering
# 14  3.304295e+18            Koneru Lakshmiah College of Engineering
# ...

# %%
df_1 = df_1.replace(np.nan, 0)
df_1.head()
# Out:
#      Contact Id                                       Account Name  \
# 0  3.304295e+18                          Assam Engineering College
# 1  3.304295e+18  Jawaharlal Nehru Technological University Kaki...
# 2  3.304295e+18                 RGM Group of Institutions, Nandyal
# 3  3.304295e+18                       Abhyaz Internship Applicants
# 6  3.304295e+18                R.V.R. & J.C.College of Engineering
#
#        Mobile                            Email  \
# 0  9365995608                    tnp@aec.ac.in
# 1  8842351502  placementofficer@jntucek.edu.in
# 2  9885937384                tpospec@gmail.com
# 3  8587077061              sdureja03@gmail.com
# 6           0           gsprasad@rvrjcce.ac.in
#
#                                       Title Contact Role Contact Frequency  \
# 0              Training & Placement Officer   Influencer        Frequently
# 1            Training and Placement Officer            0                 0
# ...

# %%
df_1.to_csv('TPOS1st.csv', index=False, header=True)

# %%
df_2.shape
# Out:
# (644, 10)

# %%
df_2.to_csv('TPOS-new.csv', index=False, header=True)

# %%
# dropping the rows with no email id

df_2.dropna(subset=['Email'], inplace=True)

# %%
df_2.shape
# Out:
# (635, 10)

# %%
df_2.to_csv('TPOS-dropped.csv', index=False, header=True)

# %%
chunk_size = 59
TPOS_split = 1

for chunk in pd.read_csv('TPOS-dropped.csv', chunksize=chunk_size):
    chunk.to_csv('TPOS' + str(TPOS_split) + '.csv', index=False)
    TPOS_split += 1

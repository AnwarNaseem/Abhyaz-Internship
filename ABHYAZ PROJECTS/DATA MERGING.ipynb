# %%
# Data merging using Full Join

# %%
import pandas as pd
import numpy as np

# %%
import os
os.getcwd()
os.chdir("D:\ABHYAZ INTERNSHIP\MTC")

# %%
df1 = pd.read_excel(r'Company Director 108057.xlsx')
df1.head()
# Out:
#                                         Company Name            Name  \
# 0                    Awan Aluminiums Private Limited    manish dixit
# 1       CloudByte India Technologies Private Limited  MANISH CHOGALE
# 2  Ministry of Defence - Directorate General of M...   Manish Chopra
# 3                                         Mexx Cards   Manish Choure
# 4                      Entasis India Private Limited  MANISH CHANDRA
#
#                            Designation        State  \
# 0                    Managing Director      Haryana
# 1  Senior Director - Quality Assurance    Karnataka
# 2                     Director - Works        Delhi
# 3                             Director  Maharashtra
# 4         Promoter & Managing Director        Delhi
#
#                         Email      Mobile            IndustryType
# 0      manishchem07@gmail.com  9454374665           Manufacturing
# 1     manishchogale@gmail.com  9869156870  Information Technology
# ...

# %%
df1 = df1.rename(columns={'IndustryType': 'Company Type','Mobile':'Mobile No'})
df1.head()
# Out:
#                                         Company Name            Name  \
# 0                    Awan Aluminiums Private Limited    manish dixit
# 1       CloudByte India Technologies Private Limited  MANISH CHOGALE
# 2  Ministry of Defence - Directorate General of M...   Manish Chopra
# 3                                         Mexx Cards   Manish Choure
# 4                      Entasis India Private Limited  MANISH CHANDRA
#
#                            Designation        State  \
# 0                    Managing Director      Haryana
# 1  Senior Director - Quality Assurance    Karnataka
# 2                     Director - Works        Delhi
# 3                             Director  Maharashtra
# 4         Promoter & Managing Director        Delhi
#
#                         Email   Mobile No            Company Type
# 0      manishchem07@gmail.com  9454374665           Manufacturing
# 1     manishchogale@gmail.com  9869156870  Information Technology
# ...

# %%
df2 = pd.read_excel(r'Company Proprietors 397196.xlsx')
df2.head()
# Out:
#                                   Company Name           Name  \
# 0               Millenium Software Productions  Manish Chavda
# 1                         Tata Capital Limited  MANISH CHAWLA
# 2             Merlin Multitech Private Limited  manish chawla
# 3              Awan Aluminiums Private Limited   manish dixit
# 4  Government of Kerala - Council of Ministers   manish kumar
#
#                           Designation         State  \
# 0                   Manager - Account    Tamil Nadu
# 1                    Managing Partner   Maharashtra
# 2             Chief Executive Officer  Chhattisgarh
# 3                   Managing Director       Haryana
# 4  Secretary - General Administration        Kerala
#
#                          Email        Mobile            IndustryType
# 0     manishchavda29@gmail.com  9.904054e+09                     NaN
# 1     manishchawla09@gmail.com  9.810299e+09               Financial
# ...

# %%
df2 = df2.rename(columns={'IndustryType':'Company Type','Mobile':'Mobile No'})
df2.head()
# Out:
#                                   Company Name           Name  \
# 0               Millenium Software Productions  Manish Chavda
# 1                         Tata Capital Limited  MANISH CHAWLA
# 2             Merlin Multitech Private Limited  manish chawla
# 3              Awan Aluminiums Private Limited   manish dixit
# 4  Government of Kerala - Council of Ministers   manish kumar
#
#                           Designation         State  \
# 0                   Manager - Account    Tamil Nadu
# 1                    Managing Partner   Maharashtra
# 2             Chief Executive Officer  Chhattisgarh
# 3                   Managing Director       Haryana
# 4  Secretary - General Administration        Kerala
#
#                          Email     Mobile No            Company Type
# 0     manishchavda29@gmail.com  9.904054e+09                     NaN
# 1     manishchawla09@gmail.com  9.810299e+09               Financial
# ...

# %%
df3 = pd.read_excel(r'Company Secretaries 382000.xlsx')
df3.head()
# Out:
#                        Company               Name      Mobile  \
# 0  Vinod K. Gupta & Associates   Ramkumar Biradar  9323465999
# 1            BMC Software pune        ankush jain  9323891764
# 2                 P&O NEDLLOYD  SANJAY KSHIRSAGAR  9324354909
# 3       Bajaj Auto Finance Ltd     vasudev jadhav  9325011292
# 4                          No.     :Pritesh Abbad  9325050072
#
#                             Email  \
# 0  ramkumar_biradar2000@yahoo.com
# 1       anjain2005@rediffmail.com
# 2           s.kshirsagar@ponl.com
# 3    vasu_20059717@rediffmail.com
# 4        priteshabbad@yahoo.co.in
#
#                                              Address  City        State  \
# 0  23, 2nd floor, Priyadarshani Building, in fron...  Pune  Maharashtra
# 1   291 somware peth , ganesh gayatri complex , pune  Pune  Maharashtra
# 2  8,Nanda deep (build), joshi wadi, Ganshaym Gup...  Pune  Maharashtra
# 3  Anant b/13 prasun dham opp.morya mangal karyal...  Pune  Maharashtra
# ...

# %%
df3 = df3.rename(columns={'Category': 'Company Type','Company':'Company Name','Mobile':'Mobile No'})
df3.head()
# Out:
#                   Company Name               Name   Mobile No  \
# 0  Vinod K. Gupta & Associates   Ramkumar Biradar  9323465999
# 1            BMC Software pune        ankush jain  9323891764
# 2                 P&O NEDLLOYD  SANJAY KSHIRSAGAR  9324354909
# 3       Bajaj Auto Finance Ltd     vasudev jadhav  9325011292
# 4                          No.     :Pritesh Abbad  9325050072
#
#                             Email  \
# 0  ramkumar_biradar2000@yahoo.com
# 1       anjain2005@rediffmail.com
# 2           s.kshirsagar@ponl.com
# 3    vasu_20059717@rediffmail.com
# 4        priteshabbad@yahoo.co.in
#
#                                              Address  City        State  \
# 0  23, 2nd floor, Priyadarshani Building, in fron...  Pune  Maharashtra
# 1   291 somware peth , ganesh gayatri complex , pune  Pune  Maharashtra
# 2  8,Nanda deep (build), joshi wadi, Ganshaym Gup...  Pune  Maharashtra
# 3  Anant b/13 prasun dham opp.morya mangal karyal...  Pune  Maharashtra
# ...

# %%
df4 = pd.read_excel(r'Consultants 57499.xlsx')
df4.head()
# Out:
#                                              Company             Name  \
# 0                                     Sunrise Estate              NaN
# 1  K.K.Associates Property & Investments Consultants  Ravinder Sharma
# 2    Motivators Educational & Immigration Consultant       Anil Kumar
# 3                    TP SMS Project & Consultant Ltd     Tejpal Singh
# 4                         Royal Property Consultants       G S Sandhu
#
#        Mobile                Email                        Address   Pincode  \
# 0  9815642458                  NaN         Sector 45 Burail 110/3  160047.0
# 1  9814108383                  NaN             Sector 44  SCO 261  160047.0
# 2  9417260000                  NaN           Sector 34  100 & 101  160022.0
# 3  9814010000  Manssaria@yahoo.com  Mohali Sector 22C Sco 2421-22  160022.0
# 4  9814440000                  NaN             Sector 35 sec 35A   160022.0
#
#          City Website                 Category State
# ...

# %%
df4 = df4.rename(columns={'Category': 'Company Type','Company':'Company Name','Mobile':'Mobile No'})
df4.head()
# Out:
#                                         Company Name             Name  \
# 0                                     Sunrise Estate              NaN
# 1  K.K.Associates Property & Investments Consultants  Ravinder Sharma
# 2    Motivators Educational & Immigration Consultant       Anil Kumar
# 3                    TP SMS Project & Consultant Ltd     Tejpal Singh
# 4                         Royal Property Consultants       G S Sandhu
#
#     Mobile No                Email                        Address   Pincode  \
# 0  9815642458                  NaN         Sector 45 Burail 110/3  160047.0
# 1  9814108383                  NaN             Sector 44  SCO 261  160047.0
# 2  9417260000                  NaN           Sector 34  100 & 101  160022.0
# 3  9814010000  Manssaria@yahoo.com  Mohali Sector 22C Sco 2421-22  160022.0
# 4  9814440000                  NaN             Sector 35 sec 35A   160022.0
#
#          City Website             Company Type State
# ...

# %%
df5 = pd.read_excel(r'Consulting Services 95641.xlsx')
df5.head()
# Out:
#                   Company               Name      Mobile Email  \
# 0          Om Sai Telecom       Sunder Singh  7838854012   NaN
# 1      Creative Marketing             Gobind  9833945483   NaN
# 2           Magus Limited              Imran  9930744868   NaN
# 3  Sachdeva Communication                NaN  9810102655   NaN
# 4            Services 24u  Mr ravinder singh  9953649795   NaN
#
#                                        Address   Pincode       City  \
# 0                           Lohia Nagar  301/5  201001.0  Ghaziabad
# 1          Chembur West Abdul Rehman Street 28  400071.0     Mumbai
# 2                               AAI Colony  36  400099.0     Mumbai
# 3                  Sarojini Nagar Ina Market 2  110023.0      Delhi
# 4  South Extension Kanpur ambader nager 16/351  110049.0      Delhi
#
#                Website             Category State
# 0                  NaN  Consulting Services   NaN
# 1                  NaN  Consulting Services   NaN
# ...

# %%
df5 = df5.rename(columns={'Category': 'Company Type','Company':'Company Name','Mobile':'Mobile No'})
df5.head()
# Out:
#              Company Name               Name   Mobile No Email  \
# 0          Om Sai Telecom       Sunder Singh  7838854012   NaN
# 1      Creative Marketing             Gobind  9833945483   NaN
# 2           Magus Limited              Imran  9930744868   NaN
# 3  Sachdeva Communication                NaN  9810102655   NaN
# 4            Services 24u  Mr ravinder singh  9953649795   NaN
#
#                                        Address   Pincode       City  \
# 0                           Lohia Nagar  301/5  201001.0  Ghaziabad
# 1          Chembur West Abdul Rehman Street 28  400071.0     Mumbai
# 2                               AAI Colony  36  400099.0     Mumbai
# 3                  Sarojini Nagar Ina Market 2  110023.0      Delhi
# 4  South Extension Kanpur ambader nager 16/351  110049.0      Delhi
#
#                Website         Company Type State
# 0                  NaN  Consulting Services   NaN
# 1                  NaN  Consulting Services   NaN
# ...

# %%
df6 = pd.read_excel(r'Manufacturing Industry 162393.xlsx')
df6.head()
# Out:
#                       Company Name             Name  \
# 0  Awan Aluminiums Private Limited     manish dixit
# 1                        Tiku Gems   MANISH CHIKANI
# 2   Godfrey Phillips India Limited  MANISH CHITKARA
# 3           T T K Prestige Limited  MANISH CHITRANS
# 4     M - Tech Innovations Limited     MANISH KUMAR
#
#                               Designation        State  \
# 0                       Managing Director      Haryana
# 1                        Managing Partner      Gujarat
# 2  Senior Manager - Corporate Development        Delhi
# 3   Senior General Manager - Supply Chain    Karnataka
# 4    General Manager - Finance & Accounts  Maharashtra
#
#                          Email      MobileNo   IndustryType
# 0       manishchem07@gmail.com  919454374665  Manufacturing
# 1      manishchikani@gmail.com  919421400030  Manufacturing
# 2     manishchitkara@yahoo.com  919810132921  Manufacturing
# 3  manishchitransh@yahoo.co.in  919899354956  Manufacturing
# ...

# %%
df6 = df6.rename(columns={'IndustryType':'Company Type','MobileNo':'Mobile No'})
df6.head()
# Out:
#                       Company Name             Name  \
# 0  Awan Aluminiums Private Limited     manish dixit
# 1                        Tiku Gems   MANISH CHIKANI
# 2   Godfrey Phillips India Limited  MANISH CHITKARA
# 3           T T K Prestige Limited  MANISH CHITRANS
# 4     M - Tech Innovations Limited     MANISH KUMAR
#
#                               Designation        State  \
# 0                       Managing Director      Haryana
# 1                        Managing Partner      Gujarat
# 2  Senior Manager - Corporate Development        Delhi
# 3   Senior General Manager - Supply Chain    Karnataka
# 4    General Manager - Finance & Accounts  Maharashtra
#
#                          Email     Mobile No   Company Type
# 0       manishchem07@gmail.com  919454374665  Manufacturing
# 1      manishchikani@gmail.com  919421400030  Manufacturing
# 2     manishchitkara@yahoo.com  919810132921  Manufacturing
# 3  manishchitransh@yahoo.co.in  919899354956  Manufacturing
# ...

# %%
#merging the sheets in excel file into one

df1 = pd.concat(pd.read_excel('Company Director 108057.xlsx', sheet_name=None), ignore_index=True)
df1.head()
# Out:
#                                         Company Name            Name  \
# 0                    Awan Aluminiums Private Limited    manish dixit
# 1       CloudByte India Technologies Private Limited  MANISH CHOGALE
# 2  Ministry of Defence - Directorate General of M...   Manish Chopra
# 3                                         Mexx Cards   Manish Choure
# 4                      Entasis India Private Limited  MANISH CHANDRA
#
#                            Designation        State  \
# 0                    Managing Director      Haryana
# 1  Senior Director - Quality Assurance    Karnataka
# 2                     Director - Works        Delhi
# 3                             Director  Maharashtra
# 4         Promoter & Managing Director        Delhi
#
#                         Email        Mobile            IndustryType
# 0      manishchem07@gmail.com  9.454375e+09           Manufacturing
# 1     manishchogale@gmail.com  9.869157e+09  Information Technology
# ...

# %%
df1 = df1.rename(columns={'IndustryType':'Company Type','Mobile':'Mobile No','Company':'Company Name'})
df1.head()
# Out:
#                                         Company Name            Name  \
# 0                    Awan Aluminiums Private Limited    manish dixit
# 1       CloudByte India Technologies Private Limited  MANISH CHOGALE
# 2  Ministry of Defence - Directorate General of M...   Manish Chopra
# 3                                         Mexx Cards   Manish Choure
# 4                      Entasis India Private Limited  MANISH CHANDRA
#
#                            Designation        State  \
# 0                    Managing Director      Haryana
# 1  Senior Director - Quality Assurance    Karnataka
# 2                     Director - Works        Delhi
# 3                             Director  Maharashtra
# 4         Promoter & Managing Director        Delhi
#
#                         Email     Mobile No            Company Type
# 0      manishchem07@gmail.com  9.454375e+09           Manufacturing
# 1     manishchogale@gmail.com  9.869157e+09  Information Technology
# ...

# %%
df4 = pd.concat(pd.read_excel('Consultants 57499.xlsx', sheet_name=None), ignore_index=True)
df4 = df4.rename(columns={'Category': 'Company Type','Mobile':'Mobile No','Company':'Company Name'})
df4.head()
# Out:
#                                         Company Name             Name  \
# 0                                     Sunrise Estate              NaN
# 1  K.K.Associates Property & Investments Consultants  Ravinder Sharma
# 2    Motivators Educational & Immigration Consultant       Anil Kumar
# 3                    TP SMS Project & Consultant Ltd     Tejpal Singh
# 4                         Royal Property Consultants       G S Sandhu
#
#     Mobile No                Email                        Address   Pincode  \
# 0  9815642458                  NaN         Sector 45 Burail 110/3  160047.0
# 1  9814108383                  NaN             Sector 44  SCO 261  160047.0
# 2  9417260000                  NaN           Sector 34  100 & 101  160022.0
# 3  9814010000  Manssaria@yahoo.com  Mohali Sector 22C Sco 2421-22  160022.0
# 4  9814440000                  NaN             Sector 35 sec 35A   160022.0
#
#          City Website             Company Type State Unnamed: 10 Unnamed: 11  \
# ...

# %%
# Merging the data sets

# %%
newdf1= pd.concat([df1,df2],axis=0,join='outer')
print(newdf1.shape)
newdf1.head()
# Out:
# (613310, 7)
#                                         Company Name            Name  \
# 0                    Awan Aluminiums Private Limited    manish dixit
# 1       CloudByte India Technologies Private Limited  MANISH CHOGALE
# 2  Ministry of Defence - Directorate General of M...   Manish Chopra
# 3                                         Mexx Cards   Manish Choure
# 4                      Entasis India Private Limited  MANISH CHANDRA
#
#                            Designation        State  \
# 0                    Managing Director      Haryana
# 1  Senior Director - Quality Assurance    Karnataka
# 2                     Director - Works        Delhi
# 3                             Director  Maharashtra
# 4         Promoter & Managing Director        Delhi
#
#                         Email     Mobile No            Company Type
# 0      manishchem07@gmail.com  9.454375e+09           Manufacturing
# 1     manishchogale@gmail.com  9.869157e+09  Information Technology
# ...

# %%
newdf2= pd.concat([df3,df4],axis=0,join='outer')
print(newdf2.shape)
newdf2.head()
# Out:
# (488834, 15)
#                   Company Name               Name   Mobile No  \
# 0  Vinod K. Gupta & Associates   Ramkumar Biradar  9323465999
# 1            BMC Software pune        ankush jain  9323891764
# 2                 P&O NEDLLOYD  SANJAY KSHIRSAGAR  9324354909
# 3       Bajaj Auto Finance Ltd     vasudev jadhav  9325011292
# 4                          No.     :Pritesh Abbad  9325050072
#
#                             Email  \
# 0  ramkumar_biradar2000@yahoo.com
# 1       anjain2005@rediffmail.com
# 2           s.kshirsagar@ponl.com
# 3    vasu_20059717@rediffmail.com
# 4        priteshabbad@yahoo.co.in
#
#                                              Address  City        State  \
# 0  23, 2nd floor, Priyadarshani Building, in fron...  Pune  Maharashtra
# 1   291 somware peth , ganesh gayatri complex , pune  Pune  Maharashtra
# 2  8,Nanda deep (build), joshi wadi, Ganshaym Gup...  Pune  Maharashtra
# 3  Anant b/13 prasun dham opp.morya mangal karyal...  Pune  Maharashtra
# ...

# %%
newdf3= pd.concat([df5,df6],axis=0,join='outer')
print(newdf3.shape)
newdf3.head()
# Out:
# (258034, 11)
#              Company Name               Name   Mobile No Email  \
# 0          Om Sai Telecom       Sunder Singh  7838854012   NaN
# 1      Creative Marketing             Gobind  9833945483   NaN
# 2           Magus Limited              Imran  9930744868   NaN
# 3  Sachdeva Communication                NaN  9810102655   NaN
# 4            Services 24u  Mr ravinder singh  9953649795   NaN
#
#                                        Address   Pincode       City  \
# 0                           Lohia Nagar  301/5  201001.0  Ghaziabad
# 1          Chembur West Abdul Rehman Street 28  400071.0     Mumbai
# 2                               AAI Colony  36  400099.0     Mumbai
# 3                  Sarojini Nagar Ina Market 2  110023.0      Delhi
# 4  South Extension Kanpur ambader nager 16/351  110049.0      Delhi
#
#                Website         Company Type State Designation
# 0                  NaN  Consulting Services   NaN         NaN
# ...

# %%
newdf4= pd.concat([newdf1,newdf2],axis=0,join='outer')
print(newdf4.shape)
newdf4.head()
# Out:
# (1102144, 16)
#                                         Company Name            Name  \
# 0                    Awan Aluminiums Private Limited    manish dixit
# 1       CloudByte India Technologies Private Limited  MANISH CHOGALE
# 2  Ministry of Defence - Directorate General of M...   Manish Chopra
# 3                                         Mexx Cards   Manish Choure
# 4                      Entasis India Private Limited  MANISH CHANDRA
#
#                            Designation        State  \
# 0                    Managing Director      Haryana
# 1  Senior Director - Quality Assurance    Karnataka
# 2                     Director - Works        Delhi
# 3                             Director  Maharashtra
# 4         Promoter & Managing Director        Delhi
#
#                         Email     Mobile No            Company Type Address  \
# 0      manishchem07@gmail.com  9454374665.0           Manufacturing     NaN
# ...

# %%
newdf5= pd.concat([newdf3,newdf4],axis=0,join='outer')
print(newdf5.shape)
newdf5.head()
# Out:
# (1360178, 16)
#              Company Name               Name   Mobile No Email  \
# 0          Om Sai Telecom       Sunder Singh  7838854012   NaN
# 1      Creative Marketing             Gobind  9833945483   NaN
# 2           Magus Limited              Imran  9930744868   NaN
# 3  Sachdeva Communication                NaN  9810102655   NaN
# 4            Services 24u  Mr ravinder singh  9953649795   NaN
#
#                                        Address   Pincode       City  \
# 0                           Lohia Nagar  301/5  201001.0  Ghaziabad
# 1          Chembur West Abdul Rehman Street 28  400071.0     Mumbai
# 2                               AAI Colony  36  400099.0     Mumbai
# 3                  Sarojini Nagar Ina Market 2  110023.0      Delhi
# 4  South Extension Kanpur ambader nager 16/351  110049.0      Delhi
#
#                Website         Company Type State Designation Unnamed: 8  \
# 0                  NaN  Consulting Services   NaN         NaN        NaN
# ...

# %%
newdf5.drop(['Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11','Unnamed: 12'], axis=1, inplace=True)

# %%
newdf5.head()
# Out:
#              Company Name               Name   Mobile No Email  \
# 0          Om Sai Telecom       Sunder Singh  7838854012   NaN
# 1      Creative Marketing             Gobind  9833945483   NaN
# 2           Magus Limited              Imran  9930744868   NaN
# 3  Sachdeva Communication                NaN  9810102655   NaN
# 4            Services 24u  Mr ravinder singh  9953649795   NaN
#
#                                        Address   Pincode       City  \
# 0                           Lohia Nagar  301/5  201001.0  Ghaziabad
# 1          Chembur West Abdul Rehman Street 28  400071.0     Mumbai
# 2                               AAI Colony  36  400099.0     Mumbai
# 3                  Sarojini Nagar Ina Market 2  110023.0      Delhi
# 4  South Extension Kanpur ambader nager 16/351  110049.0      Delhi
#
#                Website         Company Type State Designation
# 0                  NaN  Consulting Services   NaN         NaN
# ...

# %%
newdf5.shape
# Out:
# (1360178, 11)

# %%
newdf5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1360178 entries, 0 to 106833
# Data columns (total 11 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   Company Name  1205939 non-null  object
#  1   Name          1356425 non-null  object
#  2   Mobile No     1355248 non-null  object
#  3   Email         1349304 non-null  object
#  4   Address       473586 non-null   object
#  5   Pincode       13524 non-null    float64
#  6   City          584441 non-null   object
#  7   Website       3202 non-null     object
#  8   Company Type  1305754 non-null  object
#  9   State         1332901 non-null  object
#  10  Designation   775703 non-null   object
# dtypes: float64(1), object(10)
# memory usage: 124.5+ MB

# %%
# create a new column in pandas

newdf5['Country'] = 'India'

# %%
newdf5.head()
# Out:
#              Company Name               Name   Mobile No Email  \
# 0          Om Sai Telecom       Sunder Singh  7838854012   NaN
# 1      Creative Marketing             Gobind  9833945483   NaN
# 2           Magus Limited              Imran  9930744868   NaN
# 3  Sachdeva Communication                NaN  9810102655   NaN
# 4            Services 24u  Mr ravinder singh  9953649795   NaN
#
#                                        Address   Pincode       City  \
# 0                           Lohia Nagar  301/5  201001.0  Ghaziabad
# 1          Chembur West Abdul Rehman Street 28  400071.0     Mumbai
# 2                               AAI Colony  36  400099.0     Mumbai
# 3                  Sarojini Nagar Ina Market 2  110023.0      Delhi
# 4  South Extension Kanpur ambader nager 16/351  110049.0      Delhi
#
#                Website         Company Type State Designation Country
# 0                  NaN  Consulting Services   NaN         NaN   India
# ...

# %%
# newdf5.to_csv('MTC_merged.csv', index=False, header=True)

# %%
# Merging other data files (priyesh data)

# %%
newdf6 = pd.read_excel(r'pec-part 2 clean.xlsx')
newdf6.head()
# Out:
#     SL                   company name                 Name  \
# 0  1.0        3M Tools and Components          Anil Mottou
# 1  2.0                A &S Technology   Surjit Singh arora
# 2  3.0              A& N Technologies         Navjot Singh
# 3  4.0  A.G.Industries, Indl Phase IX         Aviral Gupta
# 4  5.0                   A.K.Infotech  Amandeep Singh Gill
#
#                         Email    Contact No 2   Mobile No
# 0     threemmtool@yahoo.co.in  0172-\n5093427  9316133159
# 1  surjitsingharora@ymail.com  0172-\n5090364  9888002660
# 2       nav_pahwa@hotmail.com             NaN  9878631885
# 3            aginds@gmail.com             NaN  9781900275
# 4    amangill1022@hotmail.com  0172-\n2237398  9872671022

# %%
newdf6 = newdf6.rename(columns={'Contact No 2':'Phone','company name':'Company Name'})
newdf6.head()
# Out:
#     SL                   Company Name                 Name  \
# 0  1.0        3M Tools and Components          Anil Mottou
# 1  2.0                A &S Technology   Surjit Singh arora
# 2  3.0              A& N Technologies         Navjot Singh
# 3  4.0  A.G.Industries, Indl Phase IX         Aviral Gupta
# 4  5.0                   A.K.Infotech  Amandeep Singh Gill
#
#                         Email           Phone   Mobile No
# 0     threemmtool@yahoo.co.in  0172-\n5093427  9316133159
# 1  surjitsingharora@ymail.com  0172-\n5090364  9888002660
# 2       nav_pahwa@hotmail.com             NaN  9878631885
# 3            aginds@gmail.com             NaN  9781900275
# 4    amangill1022@hotmail.com  0172-\n2237398  9872671022

# %%
newdf7= pd.concat([newdf5,newdf6],axis=0,join='outer')
print(newdf7.shape)
newdf7.head()
# Out:
# (1360672, 14)
#              Company Name               Name   Mobile No Email  \
# 0          Om Sai Telecom       Sunder Singh  7838854012   NaN
# 1      Creative Marketing             Gobind  9833945483   NaN
# 2           Magus Limited              Imran  9930744868   NaN
# 3  Sachdeva Communication                NaN  9810102655   NaN
# 4            Services 24u  Mr ravinder singh  9953649795   NaN
#
#                                        Address   Pincode       City  \
# 0                           Lohia Nagar  301/5  201001.0  Ghaziabad
# 1          Chembur West Abdul Rehman Street 28  400071.0     Mumbai
# 2                               AAI Colony  36  400099.0     Mumbai
# 3                  Sarojini Nagar Ina Market 2  110023.0      Delhi
# 4  South Extension Kanpur ambader nager 16/351  110049.0      Delhi
#
#                Website         Company Type State Designation Country  SL  \
# 0                  NaN  Consulting Services   NaN         NaN   India NaN
# ...

# %%
newdf7 = newdf7.rename(columns={'Email':'Email ID'})
newdf7.head()
# Out:
#              Company Name               Name   Mobile No Email ID  \
# 0          Om Sai Telecom       Sunder Singh  7838854012      NaN
# 1      Creative Marketing             Gobind  9833945483      NaN
# 2           Magus Limited              Imran  9930744868      NaN
# 3  Sachdeva Communication                NaN  9810102655      NaN
# 4            Services 24u  Mr ravinder singh  9953649795      NaN
#
#                                        Address   Pincode       City  \
# 0                           Lohia Nagar  301/5  201001.0  Ghaziabad
# 1          Chembur West Abdul Rehman Street 28  400071.0     Mumbai
# 2                               AAI Colony  36  400099.0     Mumbai
# 3                  Sarojini Nagar Ina Market 2  110023.0      Delhi
# 4  South Extension Kanpur ambader nager 16/351  110049.0      Delhi
#
#                Website         Company Type State Designation Country  SL  \
# 0                  NaN  Consulting Services   NaN         NaN   India NaN
# ...

# %%
newdf7.drop(['SL'], axis=1, inplace=True)
print(newdf7.shape)
newdf7.head()
# Out:
# (1360672, 13)
#              Company Name               Name   Mobile No Email ID  \
# 0          Om Sai Telecom       Sunder Singh  7838854012      NaN
# 1      Creative Marketing             Gobind  9833945483      NaN
# 2           Magus Limited              Imran  9930744868      NaN
# 3  Sachdeva Communication                NaN  9810102655      NaN
# 4            Services 24u  Mr ravinder singh  9953649795      NaN
#
#                                        Address   Pincode       City  \
# 0                           Lohia Nagar  301/5  201001.0  Ghaziabad
# 1          Chembur West Abdul Rehman Street 28  400071.0     Mumbai
# 2                               AAI Colony  36  400099.0     Mumbai
# 3                  Sarojini Nagar Ina Market 2  110023.0      Delhi
# 4  South Extension Kanpur ambader nager 16/351  110049.0      Delhi
#
#                Website         Company Type State Designation Country Phone
# ...

# %%
newdf7.to_csv('Industries_merged.csv', index=False, header=True)

# %%
newdf8 = pd.read_csv(r'Industries_merged.csv')
print(newdf8.shape)
newdf8.head()
# Out:
# C:\Users\anwar\AppData\Local\Temp\ipykernel_6460\2061755819.py:1: DtypeWarning: Columns (2,4,6,7,10,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   newdf8 = pd.read_csv(r'Industries_merged.csv')
# (1360672, 13)
#              Company Name               Name   Mobile No Email ID  \
# 0          Om Sai Telecom       Sunder Singh  7838854012      NaN
# 1      Creative Marketing             Gobind  9833945483      NaN
# 2           Magus Limited              Imran  9930744868      NaN
# 3  Sachdeva Communication                NaN  9810102655      NaN
# 4            Services 24u  Mr ravinder singh  9953649795      NaN
#
#                                        Address   Pincode       City  \
# 0                           Lohia Nagar  301/5  201001.0  Ghaziabad
# 1          Chembur West Abdul Rehman Street 28  400071.0     Mumbai
# 2                               AAI Colony  36  400099.0     Mumbai
# ...

# %%
newdf8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1360672 entries, 0 to 1360671
# Data columns (total 13 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   Company Name  1206423 non-null  object
#  1   Name          1356907 non-null  object
#  2   Mobile No     1355702 non-null  object
#  3   Email ID      1349738 non-null  object
#  4   Address       473586 non-null   object
#  5   Pincode       13524 non-null    float64
#  6   City          584441 non-null   object
#  7   Website       3202 non-null     object
#  8   Company Type  1305754 non-null  object
#  9   State         1332901 non-null  object
#  10  Designation   775703 non-null   object
#  11  Country       1360178 non-null  object
#  12  Phone         412 non-null      object
# dtypes: float64(1), object(12)
# memory usage: 135.0+ MB

# %%
# priyesh data
newdf9 = pd.read_csv(r'pec-industries-part2.csv')
print(newdf9.shape)
newdf9.head()
# Out:
# (225, 7)
#    Unnamed: 0                                       Company Name  \
# 0           0  SMALL        INDL.        ASSOCN        OF LUD...
# 1           1        FOCAL   POINT   ENTREPRENEURS ASSCON\nK-293
# 2           2  FOCAL     POINT     IND.     WELFARE ASOCN\nE-647
# 3           3  FOCAL      POINT      .VIII      INDL. ASSOCN\...
# 4           4                    SQUARE NUTS MFRS.ASSCON ST.NO.1
#
#                               Name Email ID Designation  \
# 0               PAWAN       GARG-       NaN   PRESIDENT
# 1         SURINDER      PAL SINGH-      NaN   PRESIDENT
# 2               ISHWAR     SINGH-       NaN  PRESIDENT
# 3            O.P.          BASSI-       NaN  PRESIDENT
# 4               BRIJ     BHUSHAN-       NaN  PRESIDENT
#
#                                 Mobile No  \
# 0              0161- 2490939 \n9417027411
# 1                              9855738166
# 2                            98150-00936
# 3                              9876910610
# ...

# %%
newdf9.drop(['Unnamed: 0'], axis=1, inplace=True)
print(newdf9.shape)
newdf9.head()
# Out:
# (225, 6)
#                                         Company Name  \
# 0  SMALL        INDL.        ASSOCN        OF LUD...
# 1        FOCAL   POINT   ENTREPRENEURS ASSCON\nK-293
# 2  FOCAL     POINT     IND.     WELFARE ASOCN\nE-647
# 3  FOCAL      POINT      .VIII      INDL. ASSOCN\...
# 4                    SQUARE NUTS MFRS.ASSCON ST.NO.1
#
#                               Name Email ID Designation  \
# 0               PAWAN       GARG-       NaN   PRESIDENT
# 1         SURINDER      PAL SINGH-      NaN   PRESIDENT
# 2               ISHWAR     SINGH-       NaN  PRESIDENT
# 3            O.P.          BASSI-       NaN  PRESIDENT
# 4               BRIJ     BHUSHAN-       NaN  PRESIDENT
#
#                                 Mobile No  \
# 0              0161- 2490939 \n9417027411
# 1                              9855738166
# 2                            98150-00936
# 3                              9876910610
# 4  0161-249119\n98140 98455 \n98140 12193
#
# ...

# %%
newdf9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225 entries, 0 to 224
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company Name  225 non-null    object
#  1   Name          212 non-null    object
#  2   Email ID      82 non-null     object
#  3   Designation   225 non-null    object
#  4   Mobile No     225 non-null    object
#  5   Address       225 non-null    object
# dtypes: object(6)
# memory usage: 10.7+ KB

# %%
newdf10= pd.concat([newdf8,newdf9],axis=0)
print(newdf10.shape)
newdf10.head()
# Out:
# (1360897, 13)
#              Company Name               Name   Mobile No Email ID  \
# 0          Om Sai Telecom       Sunder Singh  7838854012      NaN
# 1      Creative Marketing             Gobind  9833945483      NaN
# 2           Magus Limited              Imran  9930744868      NaN
# 3  Sachdeva Communication                NaN  9810102655      NaN
# 4            Services 24u  Mr ravinder singh  9953649795      NaN
#
#                                        Address   Pincode       City  \
# 0                           Lohia Nagar  301/5  201001.0  Ghaziabad
# 1          Chembur West Abdul Rehman Street 28  400071.0     Mumbai
# 2                               AAI Colony  36  400099.0     Mumbai
# 3                  Sarojini Nagar Ina Market 2  110023.0      Delhi
# 4  South Extension Kanpur ambader nager 16/351  110049.0      Delhi
#
#                Website         Company Type State Designation Country Phone
# ...

# %%
newdf10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1360897 entries, 0 to 224
# Data columns (total 13 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   Company Name  1206648 non-null  object
#  1   Name          1357119 non-null  object
#  2   Mobile No     1355927 non-null  object
#  3   Email ID      1349820 non-null  object
#  4   Address       473811 non-null   object
#  5   Pincode       13524 non-null    float64
#  6   City          584441 non-null   object
#  7   Website       3202 non-null     object
#  8   Company Type  1305754 non-null  object
#  9   State         1332901 non-null  object
#  10  Designation   775928 non-null   object
#  11  Country       1360178 non-null  object
#  12  Phone         412 non-null      object
# dtypes: float64(1), object(12)
# memory usage: 145.4+ MB

# %%
# saroj India data
newdf11 = pd.read_csv(r'industry_india.csv')
print(newdf11.shape)
newdf11.head()
# Out:
# (6057, 13)
#                    Company Name    Company Type Name of the person Address  \
# 0  INTERNATIONAL COMBUSTION LTD     ENGINEERING      S. K. GOSWAMI     NaN
# 1      DIFFUSSION ENGINEERS LTD      AUTOMOBILE           N.K.GARG     NaN
# 2             TECHNOCRAFT INDIA      AUTOMOBILE       NAGRAJ REDDY     NaN
# 3          V S AUTOTECH PVT LTD     SHEEETMETAL    SURYABHAN SHETE     NaN
# 4       BOMBAY OXYGEN CORPN LTD  GAS INDUSTRIES         SHYAM RUIA     NaN
#
#     Mobile No                                  Email ID Designation State  \
# 0  9373107656  nagpuroffice@internationalzlcomubtion.in         NaN   NaN
# 1  9823721556               info@diffusionengineers.com         NaN   NaN
# 2  9314451080                     tecindia1@hotmail.com         NaN   NaN
# 3  9823030114                      vsautotech@gmail.com         NaN   NaN
# 4  9595227615                                       NaN         NaN   NaN
#
#   District Country  Pincode Phone  Web
# ...

# %%
newdf11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6057 entries, 0 to 6056
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Company Name        6045 non-null   object
#  1   Company Type        5588 non-null   object
#  2   Name of the person  4932 non-null   object
#  3   Address             4832 non-null   object
#  4   Mobile No           5602 non-null   object
#  5   Email ID            2182 non-null   object
#  6   Designation         317 non-null    object
#  7   State               551 non-null    object
#  8   District            408 non-null    object
#  9   Country             6057 non-null   object
#  10  Pincode             0 non-null      float64
#  11  Phone               386 non-null    object
#  12  Web                 0 non-null      float64
# dtypes: float64(2), object(11)
# memory usage: 615.3+ KB

# %%
newdf11 = newdf11.rename(columns={'Name of the person':'Name','Web':'Website'})
newdf11.head()
# Out:
#                    Company Name    Company Type             Name Address  \
# 0  INTERNATIONAL COMBUSTION LTD     ENGINEERING    S. K. GOSWAMI     NaN
# 1      DIFFUSSION ENGINEERS LTD      AUTOMOBILE         N.K.GARG     NaN
# 2             TECHNOCRAFT INDIA      AUTOMOBILE     NAGRAJ REDDY     NaN
# 3          V S AUTOTECH PVT LTD     SHEEETMETAL  SURYABHAN SHETE     NaN
# 4       BOMBAY OXYGEN CORPN LTD  GAS INDUSTRIES       SHYAM RUIA     NaN
#
#     Mobile No                                  Email ID Designation State  \
# 0  9373107656  nagpuroffice@internationalzlcomubtion.in         NaN   NaN
# 1  9823721556               info@diffusionengineers.com         NaN   NaN
# 2  9314451080                     tecindia1@hotmail.com         NaN   NaN
# 3  9823030114                      vsautotech@gmail.com         NaN   NaN
# 4  9595227615                                       NaN         NaN   NaN
#
#   District Country  Pincode Phone  Website
# ...

# %%
newdf12= pd.concat([newdf9,newdf10],axis=0)
print(newdf12.shape)
newdf12.head()
# Out:
# (1361122, 13)
#                                         Company Name  \
# 0  SMALL        INDL.        ASSOCN        OF LUD...
# 1        FOCAL   POINT   ENTREPRENEURS ASSCON\nK-293
# 2  FOCAL     POINT     IND.     WELFARE ASOCN\nE-647
# 3  FOCAL      POINT      .VIII      INDL. ASSOCN\...
# 4                    SQUARE NUTS MFRS.ASSCON ST.NO.1
#
#                               Name Email ID Designation  \
# 0               PAWAN       GARG-       NaN   PRESIDENT
# 1         SURINDER      PAL SINGH-      NaN   PRESIDENT
# 2               ISHWAR     SINGH-       NaN  PRESIDENT
# 3            O.P.          BASSI-       NaN  PRESIDENT
# 4               BRIJ     BHUSHAN-       NaN  PRESIDENT
#
#                                 Mobile No  \
# 0              0161- 2490939 \n9417027411
# 1                              9855738166
# 2                            98150-00936
# 3                              9876910610
# 4  0161-249119\n98140 98455 \n98140 12193
#
# ...

# %%
newdf12 = newdf12.replace('-', ' ', regex=True)

# %%
newdf12.head(10)
# Out:
#                                         Company Name  \
# 0  SMALL        INDL.        ASSOCN        OF LUD...
# 1        FOCAL   POINT   ENTREPRENEURS ASSCON\nK 293
# 2  FOCAL     POINT     IND.     WELFARE ASOCN\nE 647
# 3  FOCAL      POINT      .VIII      INDL. ASSOCN\...
# 4                    SQUARE NUTS MFRS.ASSCON ST.NO.1
# 5                                               EEPC
# 6  NORTHERN           INDIA           ENGG.\nEXPO...
# 7                      PUNJAB NEW INDS. ASSCON\n15 R
# 8                 LUDHIANA ENGG. ASSOCIATION\n 22 23
# 9  HOSIERY INDS. ASSOCIATION . SARJEEVAN KNITWEAR...
#
#                                             Name Email ID Designation  \
# 0                             PAWAN       GARG        NaN   PRESIDENT
# 1                       SURINDER      PAL SINGH       NaN   PRESIDENT
# 2                             ISHWAR     SINGH        NaN  PRESIDENT
# 3                          O.P.          BASSI        NaN  PRESIDENT
# ...

# %%
# trim white spaces

newdf12 =newdf12.apply(lambda x: x.str.strip() if x.dtype == 'object' else x)

# %%
newdf12.to_csv('Industries_complete_unclean_India.csv', index=False, header=True)

# %%
newdf12.shape
# Out:
# (1361122, 13)

# %%
newdf12.duplicated().sum()
# Out:
# 371263

# %%
newdf12 = newdf12.drop_duplicates()

# %%
newdf12.shape
# Out:
# (989859, 13)

# %%
newdf12.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 989859 entries, 0 to 1360671
# Data columns (total 13 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Company Name  850946 non-null  object
#  1   Name          986490 non-null  object
#  2   Email ID      978834 non-null  object
#  3   Designation   461167 non-null  object
#  4   Mobile No     578705 non-null  object
#  5   Address       427087 non-null  object
#  6   Pincode       11832 non-null   float64
#  7   City          528170 non-null  object
#  8   Website       2387 non-null    object
#  9   Company Type  956715 non-null  object
#  10  State         965993 non-null  object
#  11  Country       989201 non-null  object
#  12  Phone         412 non-null     object
# dtypes: float64(1), object(12)
# memory usage: 105.7+ MB

# %%
newdf12.isnull().any()
# Out:
# Company Name    True
# Name            True
# Email ID        True
# Designation     True
# Mobile No       True
# Address         True
# Pincode         True
# City            True
# Website         True
# Company Type    True
# State           True
# Country         True
# Phone           True
# dtype: bool

# %%
newdf12.isnull().sum()
# Out:
# Company Name    138913
# Name              3369
# Email ID         11025
# Designation     528692
# Mobile No       411154
# Address         562772
# Pincode         978027
# City            461689
# Website         987472
# Company Type     33144
# State            23866
# Country            658
# Phone           989447
# dtype: int64

# %%
newdf12.shape
# Out:
# (989859, 13)

# %%
newdf12.to_csv('Industries_complete_cleaned_India.csv', index=False, header=True)

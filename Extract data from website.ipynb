# %% [markdown]
# # WEB SCRAPING

# %%
# !pip3 install beautifulsoup4
# !pip3 install requests
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\anwar\anaconda3\lib\site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\anwar\anaconda3\lib\site-packages (from beautifulsoup4) (2.3.1)
# Requirement already satisfied: requests in c:\users\anwar\anaconda3\lib\site-packages (2.25.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\anwar\anaconda3\lib\site-packages (from requests) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\anwar\anaconda3\lib\site-packages (from requests) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\anwar\anaconda3\lib\site-packages (from requests) (1.26.8)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\anwar\anaconda3\lib\site-packages (from requests) (4.0.0)

# %%
import sys
import requests
from bs4 import BeautifulSoup
from urllib.request import urlopen
import re
import unicodedata

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Using web scraping to find the top 5 ranking institutions**

# %%
nirf_url = "https://www.nirfindia.org/2021/EngineeringRanking.html"

# %% [markdown]
# **Obtain a response object by making a request for the HTML page from the above URL**

# %%
response = requests.get(nirf_url)

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
soup.title
# Out:
# <title> MoE, National Institute Ranking Framework (NIRF) </title>

# %% [markdown]
# **Importing relevant data**

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <script async="" src="//www.google-analytics.com/analytics.js">
#   </script>
#   <script>
#    (function (i, s, o, g, r, a, m) {i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function () {(i[r].q = i[r].q || []).push(arguments)}, i[r].l = 1 * new Date(); a = s.createElement(o),m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m)})(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');ga('create', 'UA-75867016-1', 'auto');ga('send', 'pageview');
#   </script>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    MoE, National Institute Ranking Framework (NIRF)
#   </title>
#   <link href="https://www.nirfindia.org/css/style.css" rel="stylesheet" type="text/css"/>
#   <script src="https://www.nirfindia.org/js/modernizr.js" type="text/javascript">
#   </script>
#   <script src="https://www.nirfindia.org/js/jquery-min.js" type="text/javascript">
#   </script>
#   <script src="https://www.nirfindia.org/js/md5.js" type="text/javascript">
#   </script>
#   <link href="https://www.nirfindia.org/css/style.css" rel="stylesheet" type="text/css"/>
#   <link href="https://www.nirfindia.org/css/jquery.dataTables.min.css" rel="stylesheet" type="text/css"/>
#   <link href="https://www.nirfindia.org/css/dataTables.responsive.css" rel="stylesheet" type="text/css"/>
#   <script src="https://www.nirfindia.org/js/jquery-1.12.0.min.js" type="text/javascript">
#   </script>
#   <script src="https://www.nirfindia.org/js/jquery.dataTables.min.js" type="text/javascript">
#   </script>
#   <script src="https://www.nirfindia.org/js/dataTables.responsive.js" type="text/javascript">
#   </script>
#   <style>
#    .btn-more-details { color: #0e0e66; cursor: pointer; font-weight: 800; }.btn-danger {background-color: #ae333f;border-color: #a93a3a;color: #fff;}.btn-danger {background-color: #d9534f;border-color: #d43f3a;color: #fff;}.btn {-moz-user-select: none;border: 1px solid transparent;border-radius: 4px;cursor: pointer;display: inline-block;font-size: 14px;font-weight: normal;line-height: 1.42857;margin-bottom: 0;padding: 6px 12px;text-align: center;vertical-align: middle;white-space: nowrap;}
#   </style>
#  </head>
#  <body>
#   <div id="wrapper">
#    <div id="header">
#     <div class="topbar">
#      <div class="container">
#       <div class="topLinks">
#        <ul class="portalLinks">
#         <li>
#          <a href="/GalleryView">
#           <span class="userProfile sprite">
#           </span>
#           Gallery
#          </a>
#         </li>
#         <li>
#          <a href="/Contact">
#           <span class="siteMaping sprite">
#           </span>
#           Contact
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#     <div class="logobar">
#      <div class="container">
#       <div class="emblem">
#        <img alt="Government of India" height="104" src="https://www.nirfindia.org/images/emblem.png" title="Government of India" width="65"/>
#       </div>
#       <div class="logoText">
#        National Institutional Ranking Framework
#        <br/>
#        <span class="logoTextSubTitle">
#         Ministry of Education
#        </span>
#        <br/>
#        <span class="logoTextSmall">
#         Government of India
#        </span>
#       </div>
#       <h1 id="logo" title="MoE, National Institutional Ranking Framework (NIRF), Government of India">
#        <a href="/Home" title="MoE, National Institutional Ranking Framework (NIRF),  Government of India">
#         <img alt="MoE, National Institutional Ranking Framework (NIRF),  Government of India" height="104" src="https://www.nirfindia.org/images/main-logo.png" title="MoE, National Institutional Ranking Framework (NIRF),  Government of India" width="154"/>
#        </a>
#       </h1>
#       <!-- End Logo -->
#      </div>
#     </div>
#     <!-- Header Navigation -->
#     <div class="mainNavigation">
#      <div class="container" id="includedContent">
#       <script type="text/javascript">
#        $(function(){$("#includedContent").load("header.html");});
#       </script>
#      </div>
#     </div>
#    </div>
#    <div id="wrapper">
#     <div class="container middleContent mrt">
#      <div class="content">
#       <div class="middleAboutSection">
#        <div id="collapse1">
#         <div id="centre_list" style="text-align: left;">
#          <a class="btn remove-btn-danger" href="https://www.nirfindia.org/2021/Ranking.html" style="cursor: pointer;">
#           <font color="blue">
#            Home Ranking
#           </font>
#          </a>
#          <a class="btn remove-btn-danger" href="EngineeringRankingALL.html" style="cursor: pointer;">
#           <font color="blue">
#            List of Participating Institutions
#           </font>
#          </a>
#         </div>
#         <div style="float:right">
#          <a href="EngineeringRanking150.html">
#           Rank-band: 201-250
#          </a>
#          |
#          <a href="EngineeringRanking200.html">
#           Rank-band: 251-300
#          </a>
#         </div>
#         <div class="div_to_hide" id="div_overall" style="display: block;">
#          <h2 class="text-center" style="padding-bottom: 0;padding-left:20%;">
#           <strong>
#            India Rankings 2021: Engineering
#           </strong>
#          </h2>
#          <table class="table table-condensed" id="tbl_overall">
#           <thead>
#            <tr>
#             <th style="20%">
#              Institute ID
#             </th>
#             <th>
#              Name
#             </th>
#             <th>
#              City
#             </th>
#             <th>
#              State
#             </th>
#             <th>
#              Score
#             </th>
#             <th>
#              Rank
#             </th>
#            </tr>
#           </thead>
#           <tbody>
#            <tr>
#             <td>
#              IR-E-U-0456
#             </td>
#             <td>
#              Indian Institute of Technology Madras
#              <div style="float:right;">
#               <a class="btn-more-details" href="javascript:;">
#                <span>
#                 More Details
#                </span>
#               </a>
#               <a class="close_data" id="close_1" style="display: none;">
#                Close
#               </a>
#               |
#               <a href="https://www.nirfindia.org/nirfpdfcdn/2021/pdf/Engineering/IR-E-U-0456.pdf" target="_blank">
#                <img src="https://www.nirfindia.org/images/pdf_icon.png" style="width: 20px; height: 20px !important"/>
#               </a>
#               |
#               <a href="https://www.nirfindia.org/nirfpdfcdn/2021/graph/Engineering/IR-E-U-0456.jpg" target="_blank">
#                <img src="https://www.nirfindia.org/images/graph.png" style="width: 20px; height: 20px !important"/>
#               </a>
#              </div>
#              <div class="tbl_hidden" style="display:none;width:100%;">
#               <br>
#                <table class="table">
#                 <thead>
#                  <tr>
#                   <th>
#                    TLR (100)
#                   </th>
#                   <th>
#                    RPC (100)
#                   </th>
#                   <th>
#                    GO (100)
#                   </th>
#                   <th>
#                    OI (100)
#                   </th>
#                   <th>
#                    PERCEPTION (100)
#                   </th>
#                  </tr>
#                 </thead>
#                 <tbody>
#                  <tr>
#                   <td>
#                    95.47
#                   </td>
#                   <td>
#                    96.43
#                   </td>
#                   <td>
#                    81.92
#                   </td>
#                   <td>
#                    62.44
#                   </td>
#                   <td>
#                    100.00
#                   </td>
#                  </tr>
#                 </tbody>
#                </table>
#               </br>
#              </div>
#             </td>
#             <td>
#              Chennai
#             </td>
#             <td>
#              Tamil Nadu
#             </td>
#             <td>
#              90.19
#             </td>
#             <td>
#              1
#             </td>
#            </tr>
#            <tr>
#             <td>
#              IR-E-I-1074
#             </td>
#             <td>
#              Indian Institute of Technology Delhi
#              <div style="float:right;">
#               <a class="btn-more-details" href="javascript:;">
#                <span>
#                 More Details
#                </span>
#               </a>
#               <a class="close_data" id="close_1" style="display: none;">
#                Close
#               </a>
#               |
#               <a href="https://www.nirfindia.org/nirfpdfcdn/2021/pdf/Engineering/IR-E-I-1074.pdf" target="_blank">
#                <img src="https://www.nirfindia.org/images/pdf_icon.png" style="width: 20px; height: 20px !important"/>
#               </a>
#               |
#               <a href="https://www.nirfindia.org/nirfpdfcdn/2021/graph/Engineering/IR-E-I-1074.jpg" target="_blank">
#                <img src="https://www.nirfindia.org/images/graph.png" style="width: 20px; height: 20px !important"/>
#               </a>
#              </div>
#              <div class="tbl_hidden" style="display:none;width:100%;">
#               <br>
#                <table class="table">
#                 <thead>
#                  <tr>
#                   <th>
#                    TLR (100)
#                   </th>
#                   <th>
#                    RPC (100)
#                   </th>
#                   <th>
#                    GO (100)
#                   </th>
#                   <th>
#                    OI (100)
#                   </th>
#                   <th>
#                    PERCEPTION (100)
#                   </th>
#                  </tr>
#                 </thead>
#                 <tbody>
#                  <tr>
#                   <td>
#                    91.76
#                   </td>
#                   <td>
#                    95.82
#                   </td>
#                   <td>
#                    80.97
#                   </td>
#                   <td>
#                    66.39
#                   </td>
#                   <td>
#                    98.63
#                   </td>
#                  </tr>
#                 </tbody>
#                </table>
#               </br>
#              </div>
#             </td>
#             <td>
#              New Delhi
#             </td>
#             <td>
#              Delhi
#             </td>
#             <td>
#              88.96
#             </td>
#             <td>
#              2
#             </td>
#            </tr>
#            <tr>
#             <td>
#              IR-E-U-
#                  </td>
#                 </tr>
#                </tbody>
#               </table>
#              </div>
#             </td>
#             <td>
#              Chennai
#             </td>
#             <td>
#              Tamil Nadu
#             </td>
#             <td>
#              58.31
#             </td>
#             <td>
#              18
#             </td>
#            </tr>
#            <tr>
#             <td>
#              IR-E-U-0378
#             </td>
#             <td>
#              Indian Institute of Technology Ropar
#              <div style="float:right;">
#               <a class="btn-more-details" href="javascript:;">
# ...
#              DIT University
#              <div style="float:right;">
#               <a class="btn-more-details" href="javascript:;">
#                <span>
#                 More Details
#                </span>
#               </a>
#               <a class="close_data" id="close_1" style="display: none;">
#                Close
#               </a>
#               |
#               <a href="https://www.nirfindia.org/nirfpdfcdn/2021/pdf/Engineering/IR-E-U-0774.pdf" target="_blank">
#                <img src="https://www.nirfindia.org/images/pdf_icon.png" style="width: 20px; height: 20px !important"/>
#               </a>
#               |
#               <a href="https://www.nirfindia.org/nirfpdfcdn/2021/graph/Engineering/IR-E-U-0774.jpg" target="_blank">
#                <img src="https://www.nirfindia.org/images/graph.png" style="width: 20px; height: 20px !important"/>
#               </a>
#              </div>
#              <div class="tbl_hidden" style="display:none;width:100%;">
#               <br/>
#               <table class="table">
#                <thead>
#                 <tr>
#                  <th>
#                   TLR (100)
#                  </th>
#                  <th>
#                   RPC (100)
#                  </th>
#                  <th>
#                   GO (100)
#                  </th>
#                  <th>
#                   OI (100)
#                  </th>
#                  <th>
#                   PERCEPTION (100)
#                  </th>
#                 </tr>
#                </thead>
#                <tbody>
#                 <tr>
#                  <td>
#                   50.14
#                  </td>
#                  <td>
#                   7.09
#                  </td>
#                  <td>
#                   48.53
#                  </td>
#                  <td>
#                   55.03
#                  </td>
#                  <td>
#                   1.46
#                  </td>
#                 </tr>
#                </tbody>
#               </table>
#              </div>
#             </td>
#             <td>
#              Dehradun
#             </td>
#             <td>
#              Uttarakhand
#             </td>
#             <td>
#              32.53
#             </td>
#             <td>
#              195
#             </td>
#            </tr>
#            <tr>
#             <td>
#              IR-E-C-1438
#             </td>
#             <td>
#              The National Institute of Engineering
#              <div style="float:right;">
#               <a class="btn-more-details" href="javascript:;">
#                <span>
#                 More Details
#                </span>
#               </a>
#               <a class="close_data" id="close_1" style="display: none;">
#                Close
#               </a>
#               |
#               <a href="https://www.nirfindia.org/nirfpdfcdn/2021/pdf/Engineering/IR-E-C-1438.pdf" target="_blank">
#                <img src="https://www.nirfindia.org/images/pdf_icon.png" style="width: 20px; height: 20px !important"/>
#               </a>
#               |
#               <a href="https://www.nirfindia.org/nirfpdfcdn/2021/graph/Engineering/IR-E-C-1438.jpg" target="_blank">
#                <img src="https://www.nirfindia.org/images/graph.png" style="width: 20px; height: 20px !important"/>
#               </a>
#              </div>
#              <div class="tbl_hidden" style="display:none;width:100%;">
#               <br/>
#               <table class="table">
#                <thead>
#                 <tr>
#                  <th>
#                   TLR (100)
#                  </th>
#                  <th>
#                   RPC (100)
#                  </th>
#                  <th>
#                   GO (100)
#                  </th>
#                  <th>
#                   OI (100)
#                  </th>
#                  <th>
#                   PERCEPTION (100)
#                  </th>
#                 </tr>
#                </thead>
#                <tbody>
#                 <tr>
#                  <td>
#                   53.79
#                  </td>
#                  <td>
#                   2.33
#                  </td>
#                  <td>
#                   51.03
#                  </td>
#                  <td>
#                   50.48
#                  </td>
#                  <td>
#                   4.23
#                  </td>
#                 </tr>
#                </tbody>
#               </table>
#              </div>
#             </td>
#             <td>
#              Mysore
#             </td>
#             <td>
#              Karnataka
#             </td>
#             <td>
#              32.52
#             </td>
#             <td>
#              196
#             </td>
#            </tr>
#            <tr>
#             <td>
#              IR-E-C-33584
#             </td>
#             <td>
#              K. J. Somaiya College of Engineering
#              <div style="float:right;">
#               <a class="btn-more-details" href="javascript:;">
#                <span>
#                 More Details
#                </span>
#               </a>
#               <a class="close_data" id="close_1" style="display: none;">
#                Close
#               </a>
#               |
#               <a href="https://www.nirfindia.org/nirfpdfcdn/2021/pdf/Engineering/IR-E-C-33584.pdf" target="_blank">
#                <img src="https://www.nirfindia.org/images/pdf_icon.png" style="width: 20px; height: 20px !important"/>
#               </a>
#               |
#               <a href="https://www.nirfindia.org/nirfpdfcdn/2021/graph/Engineering/IR-E-C-33584.jpg" target="_blank">
#                <img src="https://www.nirfindia.org/images/graph.png" style="width: 20px; height: 20px !important"/>
#               </a>
#              </div>
#              <div class="tbl_hidden" style="display:none;width:100%;">
#               <br/>
#               <table class="table">
#                <thead>
#                 <tr>
#                  <th>
#                   TLR (100)
#                  </th>
#                  <th>
#                   RPC (100)
#                  </th>
#                  <th>
#                   GO (100)
#                  </th>
#                  <th>
#                   OI (100)
#                  </th>
#                  <th>
#                   PERCEPTION (100)
#                  </th>
#                 </tr>
#                </thead>
#                <tbody>
#                 <tr>
#                  <td>
#                   52.22
#                  </td>
#                  <td>
#                   3.33
#                  </td>
#                  <td>
#                   58.94
#                  </td>
#                  <td>
#                   38.08
#                  </td>
#                  <td>
#                   2.17
#                  </td>
#                 </tr>
#                </tbody>
#               </table>
#              </div>
#             </td>
#             <td>
#              Mumbai
#             </td>
#             <td>
#              Maharashtra
#             </td>
#             <td>
#              32.48
#             </td>
#             <td>
#              197
#             </td>
#            </tr>
#            <tr>
#             <td>
#              IR-E-C-27400
#             </td>
#             <td>
#              Kakatiya Institute of Technology &amp; Science
#              <div style="float:right;">
#               <a class="btn-more-details" href="javascript:;">
#                <span>
#                 More Details
#                </span>
#               </a>
#               <a class="close_data" id="close_1" style="display: none;">
#                Close
#               </a>
#               |
#               <a href="https://www.nirfindia.org/nirfpdfcdn/2021/pdf/Engineering/IR-E-C-27400.pdf" target="_blank">
#                <img src="https://www.nirfindia.org/images/pdf_icon.png" style="width: 20px; height: 20px !important"/>
#               </a>
#               |
#               <a href="https://www.nirfindia.org/nirfpdfcdn/2021/graph/Engineering/IR-E-C-27400.jpg" target="_blank">
#                <img src="https://www.nirfindia.org/images/graph.png" style="width: 20px; height: 20px !important"/>
#               </a>
#              </div>
#              <div class="tbl_hidden" style="display:none;width:100%;">
#               <br/>
#               <table class="table">
#                <thead>
#                 <tr>
#                  <th>
#                   TLR (100)
#                  </th>
#                  <th>
#                   RPC (100)
#                  </th>
#                  <th>
#                   GO (100)
#                  </th>
#                  <th>
#                   OI (100)
#                  </th>
#                  <th>
#                   PERCEPTION (100)
#                  </th>
#                 </tr>
#                </thead>
#                <tbody>
#                 <tr>
#                  <td>
#                   55.80
#                  </td>
#                  <td>
#                   1.64
#                  </td>
#                  <td>
#                   49.13
#                  </td>
#                  <td>
#                   49.25
#                  </td>
#                  <td>
#                   4.90
#                  </td>
#                 </tr>
#                </tbody>
#               </table>
#              </div>
#             </td>
#             <td>
#              Warangal
#             </td>
#             <td>
#              Telangana
#             </td>
#             <td>
#              32.48
#             </td>
#             <td>
#              197
#             </td>
#            </tr>
#            <tr>
#             <td>
#              IR-E-C-11015
#             </td>
#             <td>
#              Walchand College of Engineering
#              <div style="float:right;">
#               <a class="btn-more-details" href="javascript:;">
#                <span>
#                 More Details
#                </span>
#               </a>
#               <a class="close_data" id="close_1" style="display: none;">
#                Close
#               </a>
#               |
#               <a href="https://www.nirfindia.org/nirfpdfcdn/2021/pdf/Engineering/IR-E-C-11015.pdf" target="_blank">
#                <img src="https://www.nirfindia.org/images/pdf_icon.png" style="width: 20px; height: 20px !important"/>
#               </a>
#               |
#               <a href="https://www.nirfindia.org/nirfpdfcdn/2021/graph/Engineering/IR-E-C-11015.jpg" target="_blank">
#                <img src="https://www.nirfindia.org/images/graph.png" style="width: 20px; height: 20px !important"/>
#               </a>
#              </div>
#              <div class="tbl_hidden" style="display:none;width:100%;">
#               <br/>
#               <table class="table">
#                <thead>
#                 <tr>
#                  <th>
#                   TLR (100)
#                  </th>
#                  <th>
#                   RPC (100)
#                  </th>
#                  <th>
#                   GO (100)
#                  </th>
#                  <th>
#                   OI (100)
#                  </th>
#                  <th>
#                   PERCEPTION (100)
#                  </th>
#                 </tr>
#                </thead>
#                <tbody>
#                 <tr>
#                  <td>
#                   48.25
#                  </td>
#                  <td>
#                   4.54
#                  </td>
#                  <td>
#                   56.11
#                  </td>
#                  <td>
#                   47.93
#                  </td>
#                  <td>
#                   6.19
#                  </td>
#                 </tr>
#                </tbody>
#               </table>
#              </div>
#             </td>
#             <td>
#              Sangli
#             </td>
#             <td>
#              Maharashtra
#             </td>
#             <td>
#              32.46
#             </td>
#             <td>
#              199
#             </td>
#            </tr>
#            <tr>
#             <td>
#              IR-E-U-0037
#             </td>
#             <td>
#              Sri Venkateswara University
#              <div style="float:right;">
#               <a class="btn-more-details" href="javascript:;">
#                <span>
#                 More Details
#                </span>
#               </a>
#               <a class="close_data" id="close_1" style="display: none;">
#                Close
#               </a>
#               |
#               <a href="https://www.nirfindia.org/nirfpdfcdn/2021/pdf/Engineering/IR-E-U-0037.pdf" target="_blank">
#                <img src="https://www.nirfindia.org/images/pdf_icon.png" style="width: 20px; height: 20px !important"/>
#               </a>
#               |
#               <a href="https://www.nirfindia.org/nirfpdfcdn/2021/graph/Engineering/IR-E-U-0037.jpg" target="_blank">
#                <img src="https://www.nirfindia.org/images/graph.png" style="width: 20px; height: 20px !important"/>
#               </a>
#              </div>
#              <div class="tbl_hidden" style="display:none;width:100%;">
#               <br/>
#               <table class="table">
#                <thead>
#                 <tr>
#                  <th>
#                   TLR (100)
#                  </th>
#                  <th>
#                   RPC (100)
#                  </th>
#                  <th>
#                   GO (100)
#                  </th>
#                  <th>
#                   OI (100)
#                  </th>
#                  <th>
#                   PERCEPTION (100)
#                  </th>
#                 </tr>
#                </thead>
#                <tbody>
#                 <tr>
#                  <td>
#                   41.76
#                  </td>
#                  <td>
#                   25.59
#                  </td>
#                  <td>
#                   37.58
#                  </td>
#                  <td>
#                   43.31
#                  </td>
#                  <td>
#                   3.56
#                  </td>
#                 </tr>
#                </tbody>
#               </table>
#              </div>
#             </td>
#             <td>
#              Tirupati
#             </td>
#             <td>
#              Andhra Pradesh
#             </td>
#             <td>
#              32.42
#             </td>
#             <td>
#              200
#             </td>
#            </tr>
#           </tbody>
#          </table>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div id="footer">
#      <ul class="portalLinks">
#       <li>
#        <a href="https://www.nirfindia.org/Home">
#         Home
#        </a>
#       </li>
#       <li>
#        <a href="https://www.nirfindia.org/About">
#         About NIRF
#        </a>
#       </li>
#       <li>
#        <a href="https://www.nirfindia.org/parameter">
#         Parameters
#        </a>
#       </li>
#       <li>
#        <a href="https://www.nirfindia.org/Documents">
#         Documents
#        </a>
#       </li>
#       <li>
#        <a href="https://www.nirfindia.org/2021/Ranking.html">
#         Ranking
#        </a>
#       </li>
#       <li>
#        <a href="https://www.nirfindia.org/Advertisement">
#         Notification/Advt
#        </a>
#       </li>
#       <li>
#        <a href="https://www.nirfindia.org/Contact">
#         Contact
#        </a>
#       </li>
#      </ul>
#      <p class="copyright">
#       Copyright © 2018, National Institutional Ranking Framework (NIRF), MoE. All rights reserved.
#      </p>
#      <!-- hitwebcounter Code START -->
#      <!-- hitwebcounter.com -->
#      <a href=".." style="font-family: Geneva, Arial, Helvetica, sans-serif; font-size: 8px; color: #686A6F; text-decoration: none;" target="_blank" title="Track My Website">
#       <strong>
#       </strong>
#      </a>
#     </div>
#    </div>
#   </div>
#   <a href="#top" id="backtotop" style="display: block;" title="Back to Top">
#    Back to Top
#   </a>
#   <script>
#    $.extend($.fn.dataTable.defaults, { responsive: true });$(document).ready(function () { $('.btn-more-details').on('click', function () { var btn = $(this); btn.parent().next().slideToggle(500, function () { if (btn.find('span').text() == 'More Details') { btn.find('span').text('Close'); } else { btn.find('span').text('More Details'); } }); });$('#tbl_overall').DataTable({ "order": [[4, "desc"]], "pageLength": 100 });  });
#   </script>
#   <script src="https://www.nirfindia.org/js/functions.js" type="text/javascript">
#   </script>
#   <script src="https://www.nirfindia.org/js/general.js" type="text/javascript">
#   </script>
#  </body>
# </html>

# %%
def extract_column_from_header(row):
    """
    This function returns the landing status from the HTML table cell 
    Input: the  element of a table data cell extracts extra row
    """
    if (row.br):
        row.br.extract()
    if row.a:
        row.a.extract()
    if row.sup:
        row.sup.extract()
        
    column_name = ' '.join(row.contents)
    
    # Filter the digit and empty names
    if not(column_name.strip().isdigit()):
        column_name = column_name.strip()
        return column_name

# %%
#putting the column names from header in a list 
column_names = []
element = soup.find_all('th')
for row in range(len(element)):
    try:
        name = extract_column_from_header(element[row])
        if (name is not None and len(name) > 0):
            column_names.append(name)
    except:
        pass

# %%
print(column_names) #this confirms we have accessed the right table
# Out:
# ['Institute ID', 'Name', 'City', 'State', 'Score', 'Rank', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (100)', 'GO (100)', 'OI (100)', 'PERCEPTION (100)', 'TLR (100)', 'RPC (10 ...

# %% [markdown]
# **Initial dataframe**

# %%
table = soup.find_all('table',"table table-condensed")
df = pd.read_html(str(table))[0]

# %%
#for top5 rankings
df_top = df.head()
df_top
# Out:
#   Institute ID                                               Name       City  \
# 0  IR-E-U-0456  Indian Institute of Technology MadrasMore Deta...    Chennai
# 1  IR-E-I-1074  Indian Institute of Technology DelhiMore Detai...  New Delhi
# 2  IR-E-U-0306  Indian Institute of Technology BombayMore Deta...     Mumbai
# 3  IR-E-I-1075  Indian Institute of Technology KanpurMore Deta...     Kanpur
# 4  IR-E-U-0573  Indian Institute of Technology KharagpurMore D...  Kharagpur
#
#            State  Score  Rank
# 0     Tamil Nadu  90.19     1
# 1          Delhi  88.96     2
# 2    Maharashtra  85.16     3
# 3  Uttar Pradesh  83.22     4
# 4    West Bengal  82.03     5

# %% [markdown]
# we can either download the data, i.e. in PDF format to our local machine using wget module like this

# %%
#list to store each institude ID using list comprehension
ins_id = [x for x in df_top['Institute ID']]
ins_id
# Out:
# ['IR-E-U-0456', 'IR-E-I-1074', 'IR-E-U-0306', 'IR-E-I-1075', 'IR-E-U-0573']

# %%
# !pip install wget
# Out:
# Requirement already satisfied: wget in c:\users\anwar\anaconda3\lib\site-packages (3.2)

# %%
#Now let's download each Institute record 

import wget 

# "C:\Users\anwar\Downloads\NIRF TOP5"

for i in ins_id:
    print(f'\nBeginning file download for Institute ID: {i}...')
    url = f'https://www.nirfindia.org/nirfpdfcdn/2021/pdf/Engineering/{i}.pdf'
    wget.download(url, f'/Users/anwar/Downloads/NIRF TOP5/{i}.pdf')
    #must create a folder named 'NIRF TOP5' in your downloads directory or alter the code to your specifics
# Out:
# Beginning file download for Institute ID: IR-E-U-0456...
#
# Beginning file download for Institute ID: IR-E-I-1074...
#
# Beginning file download for Institute ID: IR-E-U-0306...
#
# Beginning file download for Institute ID: IR-E-I-1075...
#
# Beginning file download for Institute ID: IR-E-U-0573...

# %% [markdown]
# Or read PDFs as a list of tables remotly without downloading them to local machine using tabula-py library, which converts it into dataframes automatically.

# %%
# !pip install tabula-py
# Out:
# Requirement already satisfied: tabula-py in c:\users\anwar\anaconda3\lib\site-packages (2.6.0)
# Requirement already satisfied: numpy in c:\users\anwar\anaconda3\lib\site-packages (from tabula-py) (1.21.5)
# Requirement already satisfied: pandas>=0.25.3 in c:\users\anwar\anaconda3\lib\site-packages (from tabula-py) (1.4.2)
# Requirement already satisfied: distro in c:\users\anwar\anaconda3\lib\site-packages (from tabula-py) (1.8.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\anwar\appdata\roaming\python\python39\site-packages (from pandas>=0.25.3->tabula-py) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\anwar\anaconda3\lib\site-packages (from pandas>=0.25.3->tabula-py) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\anwar\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.25.3->tabula-py) (1.15.0)

# %%
import tabula

# %%
nirf_1 = tabula.read_pdf(f'https://www.nirfindia.org/nirfpdfcdn/2021/pdf/Engineering/{ins_id[0]}.pdf', pages='all')
nirf_1 = nirf_1[2]
nirf_1
# Out:
#   Academic Year  No. of first year\rstudents intake in the\ryear  \
# 0       2014-15                                              466
# 1       2015-16                                              466
# 2       2016-17                                              466
#
#    No. of first year\rstudents admitted in\rthe year Academic Year.1  \
# 0                                                441         2015-16
# 1                                                458         2016-17
# 2                                                465         2017-18
#
#    No. of students\radmitted through\rLateral entry Academic Year.2  \
# 0                                                 0         2017-18
# 1                                                 0         2018-19
# 2                                                 0         2019-20
#
#    No. of students\rgraduating in\rminimum stipulated\rtime  \
# 0                                                334
# 1                                                362
# 2                                                374
#
#    No. of students\rplaced  \
# 0                      283
# 1                      268
# 2                      286
#
#   Median salary of\rplaced\rgraduates(Amount in\rRs.)  \
# 0              1306000(Thirteen\rlakhs six thousand)
# 1            1360000(Thirteen\rLakhs Sixty thousand)
# 2                             1500000(Fifteen lakhs)
#
#    No. of students\rselected for Higher\rStudies
# 0                                             51
# 1                                             65
# 2                                             43
